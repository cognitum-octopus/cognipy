# %% [markdown]
# # Creating and exploring the OWL/RL + SWRL Ontologies using CogniPy by Cognitum Services S.A.

# %% [markdown]
# **Setting up the environment**
# Initialization of the Ontology editor in Jupyter Notebook

# %%
from cognipy.ontology import Ontology #the ontology processing class
from cognipy.ontology import CQL #SPARQL format tailored for Contolled Natural Language
from cognipy.edit import CnlEditBox #The pywidget based ontology editor (offspirng of the Fluent Editor)
from cognipy.edit import CnlQueryForConcept #The pywidget based ontology quaty widget 
from cognipy.ontology import encode_string_for_graph_label #complex datatypes encoder for the graph labels in graph visualisation
import textwrap

def graph_attribute_formatter(val):
    if isinstance(val,list) or isinstance(val,set):
        return " | ".join(list(map(lambda i:encode_string_for_graph_label(graph_attribute_formatter(i)),val)))
    elif isinstance(val,dict):
        return " | ".join(list(map(lambda i:i[0]+" : "+encode_string_for_graph_label(graph_attribute_formatter(i[1])),val.items())))
    else:
        return encode_string_for_graph_label(textwrap.fill(str(val),40))

# %% [markdown]
# # Solar System

# %%
import pandas as pd
import os

# %%
if os.path.exists('orbits.pkl'):
    raw_orbit_data=pd.read_pickle('orbits.pkl')
else:
    raw_orbit_data=pd.read_html('http://nineplanets.org/data.html')[0]
    pd.to_pickle(raw_orbit_data,'orbits.pkl')

# %%
raw_orbit_data
# Out:
#        Name    #   Orbits Distance (000 km) O_Period (days)  Incl Eccen  \
# 0       Sun    -        -                 -               -     -     -
# 1       NaN  NaN      NaN               NaN             NaN   NaN   NaN
# 2   Mercury    I      Sun             57910           87.97     7  0.21
# 3     Venus   II      Sun            108200           224.7  3.39  0.01
# 4     Earth  III      Sun            149600          365.26     0  0.02
# ..      ...  ...      ...               ...             ...   ...   ...
# 92   Nereid   II  Neptune              5513          360.13    29  0.75
# 93      NaN  NaN      NaN               NaN             NaN   NaN   NaN
# 94   Charon    I    Pluto                20            6.39  98.8     0
# 95      Nix   II    Pluto                49           24.86   0.2     0
# 96    Hydra  III    Pluto                65           38.21  0.21     0
#
#    Discoverer  Date    A.K.A.
# 0           -     -   Sol (0)
# 1         NaN   NaN       NaN
# 2           -     -       (0)
# 3           -     -       (0)
# 4           -     -       (0)
# ..        ...   ...       ...
# 92     Kuiper  1949       NaN
# 93        NaN   NaN       NaN
# 94    Christy  1978  1978 P 1
# 95   Stern(j)  2005  2005 P 1
# 96   Stern(j)  2005  2005 P 2
#
# [97 rows x 10 columns]

# %%
def renum(x):
    x=str(x)
    x=x.strip().replace(' ','')
    x='0'+x if x[0]=='.' else x
    x=x+'0' if x[-1]=='.' else x
    return x

# %%
def orbits_to_cnl(row):
    lines = []
    if row.Name==row.Name: #Nan check
        if row.Orbits!='-':
            lines.append(f"{row.Name} orbits {row.Orbits}.")
            lines.append(f"{row.Name} has-index equal-to '{row['#']}'.")
            if row['Distance (000 km)']==row['Distance (000 km)']:
                lines.append(f"{row.Name} has-semimajor-axis-1000-km equal-to {renum(row['Distance (000 km)'])}.")
            if row['O_Period (days)']==row['O_Period (days)']:
                lines.append(f"{row.Name} has-period equal-to {renum(row['O_Period (days)'])}.")
            if row['Eccen']==row['Eccen']:
                lines.append(f"{row.Name} has-eccentricity equal-to {renum(row['Eccen'])}.")
            if row.Discoverer!='-':
                lines.append(f"{row.Name} has-discoverer equal-to '{row.Discoverer.split('(')[0]}'.")
                lines.append(f"{row.Name} has-discovery-year equal-to {row.Date}.")
    return '\n'.join(lines)

# %%
orbit_cnl='\n'.join(line for line in raw_orbit_data.apply(orbits_to_cnl,axis=1) if line!='')
print(orbit_cnl)
# Out:
# Mercury orbits Sun.
# Mercury has-index equal-to 'I'.
# Mercury has-semimajor-axis-1000-km equal-to 57910.
# Mercury has-period equal-to 87.97.
# Mercury has-eccentricity equal-to 0.21.
# Venus orbits Sun.
# Venus has-index equal-to 'II'.
# Venus has-semimajor-axis-1000-km equal-to 108200.
# Venus has-period equal-to 224.7.
# Venus has-eccentricity equal-to 0.01.
# Earth orbits Sun.
# Earth has-index equal-to 'III'.
# Earth has-semimajor-axis-1000-km equal-to 149600.
# Earth has-period equal-to 365.26.
# Earth has-eccentricity equal-to 0.02.
# Mars orbits Sun.
# Mars has-index equal-to 'IV'.
# Mars has-semimajor-axis-1000-km equal-to 227940.
# Mars has-period equal-to 686.98.
# Mars has-eccentricity equal-to 0.09.
# Jupiter orbits Sun.
# Jupiter has-index equal-to 'V'.
# Jupiter has-semimajor-axis-1000-km equal-to 778330.
# Jupiter has-period equal-to 4332.71.
# Jupiter has-eccentricity equal-to 0.05.
# Saturn orbits Sun.
# Saturn has-index equal-to 'VI'.
# Saturn has-semimajor-axis-1000-km equal-to 1429400.
# Saturn has-period equal-to 10759.5.
# Saturn has-eccentricity equal-to 0.06.
# Uranus orbits Sun.
# Uranus has-index equal-to 'VII'.
# Uranus has-semimajor-axis-1000-km equal-to 2870990.
# Uranus has-period equal-to 30685.
# Uranus has-eccentricity equal-to 0.05.
# Uranus has-discoverer equal-to 'Herschel'.
# Uranus has-discovery-year equal-to 1781.
# Neptune orbits Sun.
# Neptune has-index equal-to 'VIII'.
# Neptune has-semimajor-axis-1000-km equal-to 4504300.
# Neptune has-period equal-to 60190.
# Neptune has-eccentricity equal-to 0.01.
# Neptune has-discoverer equal-to 'Adams'.
# Neptune has-discovery-year equal-to 1846.
# Pluto orbits Sun.
# Pluto has-index equal-to 'IX'.
# Pluto has-semimajor-axis-1000-km equal-to 5913520.
# Pluto has-period equal-to 90550.
# Pluto has-eccentricity equal-to 0.25.
# Pluto has-discoverer equal-to 'Tombaugh'.
# Pluto has-discovery-year equal-to 1930.
# Moon orbits Earth.
# Moon has-index equal-to 'I'.
# Moon has-semimajor-axis-1000-km equal-to 384.
# Moon has-period equal-to 27.32.
# Moon has-eccentricity equal-to 0.05.
# Phobos orbits Mars.
# Phobos has-index equal-to 'I'.
# Phobos has-semimajor-axis-1000-km equal-to 9.
# Phobos has-period equal-to 0.32.
# Phobos has-eccentricity equal-to 0.02.
# Phobos has-discoverer equal-to 'Hall'.
# Phobos has-discovery-year equal-to 1877.
# Deimos orbits Mars.
# Deimos has-index equal-to 'II'.
# Deimos has-semimajor-axis-1000-km equal-to 23.
# Deimos has-period equal-to 1.26.
# Deimos has-eccentricity equal-to 0.
# Deimos has-discoverer equal-to 'Hall'.
# Deimos has-discovery-year equal-to 1877.
# Metis orbits Jupiter.
# Metis has-index equal-to 'XVI'.
# Metis has-semimajor-axis-1000-km equal-to 128.
# Metis has-period equal-to 0.29.
# Metis has-eccentricity equal-to 0.
# Metis has-discoverer equal-to 'Synnott'.
# Metis has-discovery-year equal-to 1979.
# Adrastea orbits Jupiter.
# Adrastea has-index equal-to 'XV'.
# Adrastea has-semimajor-axis-1000-km equal-to 129.
# Adrastea has-period equal-to 0.3.
# Adrastea has-eccentricity equal-to 0.
# Adrastea has-discoverer equal-to 'Jewitt'.
# Adrastea has-discovery-year equal-to 1979.
# Amalthea orbits Jupiter.
# Amalthea has-index equal-to 'V'.
# Amalthea has-semimajor-axis-1000-km equal-to 181.
# Amalthea has-period equal-to 0.5.
# Amalthea has-eccentricity equal-to 0.
# Amalthea has-discoverer equal-to 'Barnard'.
# Amalthea has-discovery-year equal-to 1892.
# Thebe orbits Jupiter.
# Thebe has-index equal-to 'XIV'.
# Thebe has-semimajor-axis-1000-km equal-to 222.
# Thebe has-period equal-to 0.67.
# Thebe has-eccentricity equal-to 0.02.
# Thebe has-discoverer equal-to 'Synnott'.
# Thebe has-discovery-year equal-to 1979.
# Io orbits Jupiter.
# Io has-index equal-to 'I'.
# Io has-semimajor-axis-1000-km equal-to 422.
# Io has-period equal-to 1.77.
# Io has-eccentricity equal-to 0.
# Io has-discoverer equal-to 'Galileo'.
# Io has-discovery-year equal-to 1610.
# Europa orbits Jupiter.
# Europa has-index equal-to 'II'.
# Europa has-semimajor-axis-1000-km equal-to 671.
# Europa has-period equal-to 3.55.
# Europa has-eccentricity equal-to 0.01.
# Europa has-discoverer equal-to 'Galileo'.
# Europa has-discovery-year equal-to 1610.
# Ganymede orbits Jupiter.
# Ganymede has-index equal-to 'III'.
# Ganymede has-semimajor-axis-1000-km equal-to 1070.
# Ganymede has-period equal-to 7.15.
# Ganymede has-eccentricity equal-to 0.
# Ganymede has-discoverer equal-to 'Galileo'.
# Ganymede has-discovery-year equal-to 1610.
# Callisto orbits Jupiter.
# Callisto has-index equal-to 'IV'.
# Callisto has-semimajor-axis-1000-km equal-to 1883.
# Callisto has-period equal-to 16.69.
# Callisto has-eccentricity equal-to 0.01.
# Callisto has-discoverer equal-to 'Galileo'.
# Callisto has-discovery-year equal-to 1610.
# Themisto orbits Jupiter.
# Themisto has-index equal-to 'XVIII'.
# Themisto has-semimajor-axis-1000-km equal-to 7507.
# Themisto has-discoverer equal-to 'Sheppard'.
# Themisto has-discovery-year equal-to 2000.
# Leda orbits Jupiter.
# Leda has-index equal-to 'XIII'.
# Leda has-semimajor-axis-1000-km equal-to 11094.
# Leda has-period equal-to 238.72.
# Leda has-eccentricity equal-to 0.15.
# Leda has-discoverer equal-to 'Kowal'.
# Leda has-discovery-year equal-to 1974.
# Himalia orbits Jupiter.
# Himalia has-index equal-to 'VI'.
# Himalia has-semimajor-axis-1000-km equal-to 11480.
# Himalia has-period equal-to 250.57.
# Himalia has-eccentricity equal-to 0.16.
# Himalia has-discoverer equal-to 'Perrine'.
# Himalia has-discovery-year equal-to 1904.
# Lysithea orbits Jupiter.
# Lysithea has-index equal-to 'X'.
# Lysithea has-semimajor-axis-1000-km equal-to 11720.
# Lysithea has-period equal-to 259.22.
# Lysithea has-eccentricity equal-to 0.11.
# Lysithea has-discoverer equal-to 'Nicholson'.
# Lysithea has-discovery-year equal-to 1938.
# Elara orbits Jupiter.
# Elara has-index equal-to 'VII'.
# Elara has-semimajor-axis-1000-km equal-to 11737.
# Elara has-period equal-to 259.65.
# Elara has-eccentricity equal-to 0.21.
# Elara has-discoverer equal-to 'Perrine'.
# Elara has-discovery-year equal-to 1905.
# Ananke orbits Jupiter.
# Ananke has-index equal-to 'XII'.
# Ananke has-semimajor-axis-1000-km equal-to 21200.
# Ananke has-period equal-to -631.
# Ananke has-eccentricity equal-to 0.17.
# Ananke has-discoverer equal-to 'Nicholson'.
# Ananke has-discovery-year equal-to 1951.
# Carme orbits Jupiter.
# Carme has-index equal-to 'XI'.
# Carme has-semimajor-axis-1000-km equal-to 22600.
# Carme has-period equal-to -692.
# Carme has-eccentricity equal-to 0.21.
# Carme has-discoverer equal-to 'Nicholson'.
# Carme has-discovery-year equal-to 1938.
# Pasiphae orbits Jupiter.
# Pasiphae has-index equal-to 'VIII'.
# Pasiphae has-semimajor-axis-1000-km equal-to 23500.
# Pasiphae has-period equal-to -735.
# Pasiphae has-eccentricity equal-to 0.38.
# Pasiphae has-discoverer equal-to 'Melotte'.
# Pasiphae has-discovery-year equal-to 1908.
# Sinope orbits Jupiter.
# Sinope has-index equal-to 'IX'.
# Sinope has-semimajor-axis-1000-km equal-to 23700.
# Sinope has-period equal-to -758.
# Sinope has-eccentricity equal-to 0.28.
# Sinope has-discoverer equal-to 'Nicholson'.
# Sinope has-discovery-year equal-to 1914.
# Iocaste orbits Jupiter.
# Iocaste has-index equal-to 'XXIV'.
# Iocaste has-semimajor-axis-1000-km equal-to 20216.
# Iocaste has-discoverer equal-to 'Sheppard'.
# Iocaste has-discovery-year equal-to 2000.
# Harpalyke orbits Jupiter.
# Harpalyke has-index equal-to 'XXII'.
# Harpalyke has-semimajor-axis-1000-km equal-to 21132.
# Harpalyke has-discoverer equal-to 'Sheppard'.
# Harpalyke has-discovery-year equal-to 2000.
# Praxidike orbits jupiter.
# Praxidike has-index equal-to 'XXVII'.
# Praxidike has-semimajor-axis-1000-km equal-to 20964.
# Praxidike has-discoverer equal-to 'Sheppard'.
# Praxidike has-discovery-year equal-to 2000.
# Taygete orbits Jupiter.
# Taygete has-index equal-to 'XX'.
# Taygete has-semimajor-axis-1000-km equal-to 23312.
# Taygete has-discoverer equal-to 'Sheppard'.
# Taygete has-discovery-year equal-to 2000.
# Chaldene orbits Jupiter.
# Chaldene has-index equal-to 'XXI'.
# Chaldene has-semimajor-axis-1000-km equal-to 23387.
# Chaldene has-discoverer equal-to 'Sheppard'.
# Chaldene has-discovery-year equal-to 2000.
# Kalyke orbits jupiter.
# Kalyke has-index equal-to 'XXIII'.
# Kalyke has-semimajor-axis-1000-km equal-to 23745.
# Kalyke has-discoverer equal-to 'Sheppard'.
# Kalyke has-discovery-year equal-to 2000.
# Callirrhoe orbits Jupiter.
# Callirrhoe has-index equal-to 'XVII'.
# Callirrhoe has-semimajor-axis-1000-km equal-to 24100.
# Callirrhoe has-discoverer equal-to 'Sheppard'.
# Callirrhoe has-discovery-year equal-to 2000.
# Megaclite orbits Jupiter.
# Megaclite has-index equal-to 'XIX'.
# Megaclite has-semimajor-axis-1000-km equal-to 23911.
# Megaclite has-discoverer equal-to 'Sheppard'.
# Megaclite has-discovery-year equal-to 2000.
# Isonoe orbits Jupiter.
# Isonoe has-index equal-to 'XXVI'.
# Isonoe has-semimajor-axis-1000-km equal-to 23078.
# Isonoe has-discoverer equal-to 'Sheppard'.
# Isonoe has-discovery-year equal-to 2000.
# Erinome orbits Jupiter.
# Erinome has-index equal-to 'XXV'.
# Erinome has-semimajor-axis-1000-km equal-to 23168.
# Erinome has-discoverer equal-to 'Sheppard'.
# Erinome has-discovery-year equal-to 2000.
# Pan orbits Saturn.
# Pan has-index equal-to 'XVIII'.
# Pan has-semimajor-axis-1000-km equal-to 134.
# Pan has-period equal-to 0.58.
# Pan has-eccentricity equal-to 0.
# Pan has-discoverer equal-to 'Showalter'.
# Pan has-discovery-year equal-to 1990.
# Atlas orbits Saturn.
# Atlas has-index equal-to 'XV'.
# Atlas has-semimajor-axis-1000-km equal-to 138.
# Atlas has-period equal-to 0.6.
# Atlas has-eccentricity equal-to 0.
# Atlas has-discoverer equal-to 'Terrile'.
# Atlas has-discovery-year equal-to 1980.
# Prometheus orbits Saturn.
# Prometheus has-index equal-to 'XVI'.
# Prometheus has-semimajor-axis-1000-km equal-to 139.
# Prometheus has-period equal-to 0.61.
# Prometheus has-eccentricity equal-to 0.
# Prometheus has-discoverer equal-to 'Collins'.
# Prometheus has-discovery-year equal-to 1980.
# Pandora orbits Saturn.
# Pandora has-index equal-to 'XVII'.
# Pandora has-semimajor-axis-1000-km equal-to 142.
# Pandora has-period equal-to 0.63.
# Pandora has-eccentricity equal-to 0.
# Pandora has-discoverer equal-to 'Collins'.
# Pandora has-discovery-year equal-to 1980.
# Epimetheus orbits Saturn.
# Epimetheus has-index equal-to 'XI'.
# Epimetheus has-semimajor-axis-1000-km equal-to 151.
# Epimetheus has-period equal-to 0.69.
# Epimetheus has-eccentricity equal-to 0.01.
# Epimetheus has-discoverer equal-to 'Walker'.
# Epimetheus has-discovery-year equal-to 1980.
# Janus orbits Saturn.
# Janus has-index equal-to 'X'.
# Janus has-semimajor-axis-1000-km equal-to 151.
# Janus has-period equal-to 0.69.
# Janus has-eccentricity equal-to 0.01.
# Janus has-discoverer equal-to 'Dollfus'.
# Janus has-discovery-year equal-to 1966.
# Mimas orbits Saturn.
# Mimas has-index equal-to 'I'.
# Mimas has-semimajor-axis-1000-km equal-to 186.
# Mimas has-period equal-to 0.94.
# Mimas has-eccentricity equal-to 0.02.
# Mimas has-discoverer equal-to 'Herschel'.
# Mimas has-discovery-year equal-to 1789.
# Enceladus orbits Saturn.
# Enceladus has-index equal-to 'II'.
# Enceladus has-semimajor-axis-1000-km equal-to 238.
# Enceladus has-period equal-to 1.37.
# Enceladus has-eccentricity equal-to 0.
# Enceladus has-discoverer equal-to 'Herschel'.
# Enceladus has-discovery-year equal-to 1789.
# Tethys orbits Saturn.
# Tethys has-index equal-to 'III'.
# Tethys has-semimajor-axis-1000-km equal-to 295.
# Tethys has-period equal-to 1.89.
# Tethys has-eccentricity equal-to 0.
# Tethys has-discoverer equal-to 'Cassini'.
# Tethys has-discovery-year equal-to 1684.
# Telesto orbits Saturn.
# Telesto has-index equal-to 'XIII'.
# Telesto has-semimajor-axis-1000-km equal-to 295.
# Telesto has-period equal-to 1.89.
# Telesto has-eccentricity equal-to 0.
# Telesto has-discoverer equal-to 'Smith'.
# Telesto has-discovery-year equal-to 1980.
# Calypso orbits Saturn.
# Calypso has-index equal-to 'XIV'.
# Calypso has-semimajor-axis-1000-km equal-to 295.
# Calypso has-period equal-to 1.89.
# Calypso has-eccentricity equal-to 0.
# Calypso has-discoverer equal-to 'Pascu'.
# Calypso has-discovery-year equal-to 1980.
# Dione orbits Saturn.
# Dione has-index equal-to 'IV'.
# Dione has-semimajor-axis-1000-km equal-to 377.
# Dione has-period equal-to 2.74.
# Dione has-eccentricity equal-to 0.
# Dione has-discoverer equal-to 'Cassini'.
# Dione has-discovery-year equal-to 1684.
# Helene orbits Saturn.
# Helene has-index equal-to 'XII'.
# Helene has-semimajor-axis-1000-km equal-to 377.
# Helene has-period equal-to 2.74.
# Helene has-eccentricity equal-to 0.01.
# Helene has-discoverer equal-to 'Laques'.
# Helene has-discovery-year equal-to 1980.
# Rhea orbits Saturn.
# Rhea has-index equal-to 'V'.
# Rhea has-semimajor-axis-1000-km equal-to 527.
# Rhea has-period equal-to 4.52.
# Rhea has-eccentricity equal-to 0.
# Rhea has-discoverer equal-to 'Cassini'.
# Rhea has-discovery-year equal-to 1672.
# Titan orbits Saturn.
# Titan has-index equal-to 'VI'.
# Titan has-semimajor-axis-1000-km equal-to 1222.
# Titan has-period equal-to 15.95.
# Titan has-eccentricity equal-to 0.03.
# Titan has-discoverer equal-to 'Huygens'.
# Titan has-discovery-year equal-to 1655.
# Hyperion orbits Saturn.
# Hyperion has-index equal-to 'VII'.
# Hyperion has-semimajor-axis-1000-km equal-to 1481.
# Hyperion has-period equal-to 21.28.
# Hyperion has-eccentricity equal-to 0.1.
# Hyperion has-discoverer equal-to 'Bond'.
# Hyperion has-discovery-year equal-to 1848.
# Iapetus orbits Saturn.
# Iapetus has-index equal-to 'VIII'.
# Iapetus has-semimajor-axis-1000-km equal-to 3561.
# Iapetus has-period equal-to 79.33.
# Iapetus has-eccentricity equal-to 0.03.
# Iapetus has-discoverer equal-to 'Cassini'.
# Iapetus has-discovery-year equal-to 1671.
# Phoebe orbits Saturn.
# Phoebe has-index equal-to 'IX'.
# Phoebe has-semimajor-axis-1000-km equal-to 12952.
# Phoebe has-period equal-to -550.48.
# Phoebe has-eccentricity equal-to 0.16.
# Phoebe has-discoverer equal-to 'Pickering'.
# Phoebe has-discovery-year equal-to 1898.
# Cordelia orbits Uranus.
# Cordelia has-index equal-to 'VI'.
# Cordelia has-semimajor-axis-1000-km equal-to 50.
# Cordelia has-period equal-to 0.34.
# Cordelia has-eccentricity equal-to 0.
# Cordelia has-discoverer equal-to 'Voyager 2'.
# Cordelia has-discovery-year equal-to 1986.
# Ophelia orbits Uranus.
# Ophelia has-index equal-to 'VII'.
# Ophelia has-semimajor-axis-1000-km equal-to 54.
# Ophelia has-period equal-to 0.38.
# Ophelia has-eccentricity equal-to 0.
# Ophelia has-discoverer equal-to 'Voyager 2'.
# Ophelia has-discovery-year equal-to 1986.
# Bianca orbits Uranus.
# Bianca has-index equal-to 'VIII'.
# Bianca has-semimajor-axis-1000-km equal-to 59.
# Bianca has-period equal-to 0.43.
# Bianca has-eccentricity equal-to 0.
# Bianca has-discoverer equal-to 'Voyager 2'.
# Bianca has-discovery-year equal-to 1986.
# Cressida orbits Uranus.
# Cressida has-index equal-to 'IX'.
# Cressida has-semimajor-axis-1000-km equal-to 62.
# Cressida has-period equal-to 0.46.
# Cressida has-eccentricity equal-to 0.
# Cressida has-discoverer equal-to 'Voyager 2'.
# Cressida has-discovery-year equal-to 1986.
# Desdemona orbits Uranus.
# Desdemona has-index equal-to 'X'.
# Desdemona has-semimajor-axis-1000-km equal-to 63.
# Desdemona has-period equal-to 0.47.
# Desdemona has-eccentricity equal-to 0.
# Desdemona has-discoverer equal-to 'Voyager 2'.
# Desdemona has-discovery-year equal-to 1986.
# Juliet orbits Uranus.
# Juliet has-index equal-to 'XI'.
# Juliet has-semimajor-axis-1000-km equal-to 64.
# Juliet has-period equal-to 0.49.
# Juliet has-eccentricity equal-to 0.
# Juliet has-discoverer equal-to 'Voyager 2'.
# Juliet has-discovery-year equal-to 1986.
# Portia orbits Uranus.
# Portia has-index equal-to 'XII'.
# Portia has-semimajor-axis-1000-km equal-to 66.
# Portia has-period equal-to 0.51.
# Portia has-eccentricity equal-to 0.
# Portia has-discoverer equal-to 'Voyager 2'.
# Portia has-discovery-year equal-to 1986.
# Rosalind orbits Uranus.
# Rosalind has-index equal-to 'XIII'.
# Rosalind has-semimajor-axis-1000-km equal-to 70.
# Rosalind has-period equal-to 0.56.
# Rosalind has-eccentricity equal-to 0.
# Rosalind has-discoverer equal-to 'Voyager 2'.
# Rosalind has-discovery-year equal-to 1986.
# Belinda orbits Uranus.
# Belinda has-index equal-to 'XIV'.
# Belinda has-semimajor-axis-1000-km equal-to 75.
# Belinda has-period equal-to 0.62.
# Belinda has-eccentricity equal-to 0.
# Belinda has-discoverer equal-to 'Voyager 2'.
# Belinda has-discovery-year equal-to 1986.
# Puck orbits Uranus.
# Puck has-index equal-to 'XV'.
# Puck has-semimajor-axis-1000-km equal-to 86.
# Puck has-period equal-to 0.76.
# Puck has-eccentricity equal-to 0.
# Puck has-discoverer equal-to 'Voyager 2'.
# Puck has-discovery-year equal-to 1985.
# Miranda orbits Uranus.
# Miranda has-index equal-to 'V'.
# Miranda has-semimajor-axis-1000-km equal-to 130.
# Miranda has-period equal-to 1.41.
# Miranda has-eccentricity equal-to 0.
# Miranda has-discoverer equal-to 'Kuiper'.
# Miranda has-discovery-year equal-to 1948.
# Ariel orbits Uranus.
# Ariel has-index equal-to 'I'.
# Ariel has-semimajor-axis-1000-km equal-to 191.
# Ariel has-period equal-to 2.52.
# Ariel has-eccentricity equal-to 0.
# Ariel has-discoverer equal-to 'Lassell'.
# Ariel has-discovery-year equal-to 1851.
# Umbriel orbits Uranus.
# Umbriel has-index equal-to 'II'.
# Umbriel has-semimajor-axis-1000-km equal-to 266.
# Umbriel has-period equal-to 4.14.
# Umbriel has-eccentricity equal-to 0.
# Umbriel has-discoverer equal-to 'Lassell'.
# Umbriel has-discovery-year equal-to 1851.
# Titania orbits Uranus.
# Titania has-index equal-to 'III'.
# Titania has-semimajor-axis-1000-km equal-to 436.
# Titania has-period equal-to 8.71.
# Titania has-eccentricity equal-to 0.
# Titania has-discoverer equal-to 'Herschel'.
# Titania has-discovery-year equal-to 1787.
# Oberon orbits Uranus.
# Oberon has-index equal-to 'IV'.
# Oberon has-semimajor-axis-1000-km equal-to 583.
# Oberon has-period equal-to 13.46.
# Oberon has-eccentricity equal-to 0.
# Oberon has-discoverer equal-to 'Herschel'.
# Oberon has-discovery-year equal-to 1787.
# Caliban orbits Uranus.
# Caliban has-index equal-to 'XVI'.
# Caliban has-semimajor-axis-1000-km equal-to 7169.
# Caliban has-period equal-to -580.
# Caliban has-eccentricity equal-to 0.08.
# Caliban has-discoverer equal-to 'Gladman '.
# Caliban has-discovery-year equal-to 1997.
# Stephano orbits Uranus.
# Stephano has-index equal-to 'XX'.
# Stephano has-semimajor-axis-1000-km equal-to 7948.
# Stephano has-period equal-to -674.
# Stephano has-eccentricity equal-to 0.24.
# Stephano has-discoverer equal-to 'Gladman '.
# Stephano has-discovery-year equal-to 1999.
# Sycorax orbits Uranus.
# Sycorax has-index equal-to 'XVII'.
# Sycorax has-semimajor-axis-1000-km equal-to 12213.
# Sycorax has-period equal-to -1289.
# Sycorax has-eccentricity equal-to 0.51.
# Sycorax has-discoverer equal-to 'Nicholson '.
# Sycorax has-discovery-year equal-to 1997.
# Prospero orbits Uranus.
# Prospero has-index equal-to 'XVIII'.
# Prospero has-semimajor-axis-1000-km equal-to 16568.
# Prospero has-period equal-to -2019.
# Prospero has-eccentricity equal-to 0.44.
# Prospero has-discoverer equal-to 'Holman '.
# Prospero has-discovery-year equal-to 1999.
# Setebos orbits Uranus.
# Setebos has-index equal-to 'XIX'.
# Setebos has-semimajor-axis-1000-km equal-to 17681.
# Setebos has-period equal-to -2239.
# Setebos has-eccentricity equal-to 0.57.
# Setebos has-discoverer equal-to 'Kavelaars'.
# Setebos has-discovery-year equal-to 1999.
# Trinculo orbits Uranus.
# Trinculo has-index equal-to 'XXI'.
# Trinculo has-discoverer equal-to 'Gladman '.
# Trinculo has-discovery-year equal-to 2001.
# Naiad orbits Neptune.
# Naiad has-index equal-to 'III'.
# Naiad has-semimajor-axis-1000-km equal-to 48.
# Naiad has-period equal-to 0.29.
# Naiad has-eccentricity equal-to 0.
# Naiad has-discoverer equal-to 'Voyager 2'.
# Naiad has-discovery-year equal-to 1989.
# Thalassa orbits Neptune.
# Thalassa has-index equal-to 'IV'.
# Thalassa has-semimajor-axis-1000-km equal-to 50.
# Thalassa has-period equal-to 0.31.
# Thalassa has-eccentricity equal-to 0.
# Thalassa has-discoverer equal-to 'Voyager 2'.
# Thalassa has-discovery-year equal-to 1989.
# Despina orbits Neptune.
# Despina has-index equal-to 'V'.
# Despina has-semimajor-axis-1000-km equal-to 53.
# Despina has-period equal-to 0.33.
# Despina has-eccentricity equal-to 0.
# Despina has-discoverer equal-to 'Voyager 2'.
# Despina has-discovery-year equal-to 1989.
# Galatea orbits Neptune.
# Galatea has-index equal-to 'VI'.
# Galatea has-semimajor-axis-1000-km equal-to 62.
# Galatea has-period equal-to 0.43.
# Galatea has-eccentricity equal-to 0.
# Galatea has-discoverer equal-to 'Voyager 2'.
# Galatea has-discovery-year equal-to 1989.
# Larissa orbits Neptune.
# Larissa has-index equal-to 'VII'.
# Larissa has-semimajor-axis-1000-km equal-to 74.
# Larissa has-period equal-to 0.55.
# Larissa has-eccentricity equal-to 0.
# Larissa has-discoverer equal-to 'Reitsema'.
# Larissa has-discovery-year equal-to 1989.
# Proteus orbits Neptune.
# Proteus has-index equal-to 'VIII'.
# Proteus has-semimajor-axis-1000-km equal-to 118.
# Proteus has-period equal-to 1.12.
# Proteus has-eccentricity equal-to 0.
# Proteus has-discoverer equal-to 'Voyager 2'.
# Proteus has-discovery-year equal-to 2.
# Triton orbits Neptune.
# Triton has-index equal-to 'I'.
# Triton has-semimajor-axis-1000-km equal-to 355.
# Triton has-period equal-to -5.88.
# Triton has-eccentricity equal-to 0.
# Triton has-discoverer equal-to 'Lassell'.
# Triton has-discovery-year equal-to 1846.
# Nereid orbits Neptune.
# Nereid has-index equal-to 'II'.
# Nereid has-semimajor-axis-1000-km equal-to 5513.
# Nereid has-period equal-to 360.13.
# Nereid has-eccentricity equal-to 0.75.
# Nereid has-discoverer equal-to 'Kuiper'.
# Nereid has-discovery-year equal-to 1949.
# Charon orbits Pluto.
# Charon has-index equal-to 'I'.
# Charon has-semimajor-axis-1000-km equal-to 20.
# Charon has-period equal-to 6.39.
# Charon has-eccentricity equal-to 0.
# Charon has-discoverer equal-to 'Christy'.
# Charon has-discovery-year equal-to 1978.
# Nix orbits Pluto.
# Nix has-index equal-to 'II'.
# Nix has-semimajor-axis-1000-km equal-to 49.
# Nix has-period equal-to 24.86.
# Nix has-eccentricity equal-to 0.
# Nix has-discoverer equal-to 'Stern'.
# Nix has-discovery-year equal-to 2005.
# Hydra orbits Pluto.
# Hydra has-index equal-to 'III'.
# Hydra has-semimajor-axis-1000-km equal-to 65.
# Hydra has-period equal-to 38.21.
# Hydra has-eccentricity equal-to 0.
# Hydra has-discoverer equal-to 'Stern'.
# Hydra has-discovery-year equal-to 2005.

# %%
if os.path.exists('physics.pkl'):
    raw_physical_data=pd.read_pickle('physics.pkl')
else:
    raw_physical_data= pd.read_html('https://nineplanets.org/physical-solar-system-data/',header=[0,1])[0]
    raw_physical_data.columns=["Name","Radius","Mass","Dens","Abo","Vo","Rotate","Dimensions"]
    pd.to_pickle(raw_physical_data,'physics.pkl')

# %%
raw_physical_data
# Out:
#        Name    Radius     Mass  Dens   Abo    Vo Rotate Dimensions
# 0       Sun  695000.0  1.99e30  1.41     ?   -26   24.6        NaN
# 1       NaN       NaN      NaN   NaN   NaN   NaN    NaN        NaN
# 2   Mercury    2440.0  3.30e23  5.43  0.11  -1.9   58.6        NaN
# 3     Venus    6052.0  4.87e24  5.24  0.65  -4.4   -243        NaN
# 4     Earth    6378.0  5.97e24  5.52   0.3     -   0.99        NaN
# ..      ...       ...      ...   ...   ...   ...    ...        ...
# 81   Nereid     170.0        ?     ?    .2  18.7      ?        NaN
# 82      NaN       NaN      NaN   NaN   NaN   NaN    NaN        NaN
# 83   Charon     603.0  1.52e21  1.72   .32  15.5      S        (z)
# 84      Nix      23.0   < 2e18     ?     ?  22.9      ?        (z)
# 85    Hydra      30.0   < 2e18     ?     ?  23.4      ?        (z)
#
# [86 rows x 8 columns]

# %%
def physics_to_cnl(row):
    lines = []
    if row.Name==row.Name: #Nan check
        lines.append(f"{row.Name} has-radius equal-to {renum(row.Radius)}.")
        if row.Mass!='?' and row.Mass==row.Mass:
            if row.Mass[0]=='<':
                lines.append(f"{row.Name} has-mass-kg lower-than {renum(row.Mass[1:])}.")
            else:
                lines.append(f"{row.Name} has-mass-kg equal-to {renum(row.Mass)}.")
        if row.Dens!='?' and row.Dens==row.Dens:
            lines.append(f"{row.Name} has-density equal-to {renum(row.Dens)}.")
        if row.Abo!='?':
            lines.append(f"{row.Name} has-abo equal-to {renum(row.Abo)}.")
        if row.Vo!='-' and row.Vo!='?':
            lines.append(f"{row.Name} has-vo equal-to {renum(row.Vo)}.")
        if row.Rotate!='?' and row.Rotate==row.Rotate:
            if row.Rotate=='S':
                lines.append(f"{row.Name} has-rotate equal-to 'Stable'.")
            elif row.Rotate=='chaotic':
                lines.append(f"{row.Name} has-rotate equal-to 'Chaotic'.")
            else:
                lines.append(f"{row.Name} has-rotate equal-to {renum(row.Rotate)}.")
    return '\n'.join(lines)

# %%
physics_cnl = '\n'.join(line for line in raw_physical_data.apply(physics_to_cnl,axis=1) if line!='')
print(physics_cnl)
# Out:
# Sun has-radius equal-to 695000.0.
# Sun has-mass-kg equal-to 1.99e30.
# Sun has-density equal-to 1.41.
# Sun has-vo equal-to -26.
# Sun has-rotate equal-to 24.6.
# Mercury has-radius equal-to 2440.0.
# Mercury has-mass-kg equal-to 3.30e23.
# Mercury has-density equal-to 5.43.
# Mercury has-abo equal-to 0.11.
# Mercury has-vo equal-to -1.9.
# Mercury has-rotate equal-to 58.6.
# Venus has-radius equal-to 6052.0.
# Venus has-mass-kg equal-to 4.87e24.
# Venus has-density equal-to 5.24.
# Venus has-abo equal-to 0.65.
# Venus has-vo equal-to -4.4.
# Venus has-rotate equal-to -243.
# Earth has-radius equal-to 6378.0.
# Earth has-mass-kg equal-to 5.97e24.
# Earth has-density equal-to 5.52.
# Earth has-abo equal-to 0.3.
# Earth has-rotate equal-to 0.99.
# Mars has-radius equal-to 3397.0.
# Mars has-mass-kg equal-to 6.42e23.
# Mars has-density equal-to 3.93.
# Mars has-abo equal-to 0.15.
# Mars has-vo equal-to -2.0.
# Mars has-rotate equal-to 1.03.
# Jupiter has-radius equal-to 71492.0.
# Jupiter has-mass-kg equal-to 1.90e27.
# Jupiter has-density equal-to 1.33.
# Jupiter has-abo equal-to 0.52.
# Jupiter has-vo equal-to -2.7.
# Jupiter has-rotate equal-to 0.41.
# Saturn has-radius equal-to 60268.0.
# Saturn has-mass-kg equal-to 5.68e26.
# Saturn has-density equal-to 0.69.
# Saturn has-abo equal-to 0.47.
# Saturn has-vo equal-to 0.7.
# Saturn has-rotate equal-to 0.45.
# Uranus has-radius equal-to 25559.0.
# Uranus has-mass-kg equal-to 8.68e25.
# Uranus has-density equal-to 1.32.
# Uranus has-abo equal-to 0.51.
# Uranus has-vo equal-to 5.5.
# Uranus has-rotate equal-to -0.72.
# Neptune has-radius equal-to 24766.0.
# Neptune has-mass-kg equal-to 1.02e26.
# Neptune has-density equal-to 1.64.
# Neptune has-abo equal-to 0.41.
# Neptune has-vo equal-to 7.8.
# Neptune has-rotate equal-to 0.67.
# Pluto has-radius equal-to 1150.0.
# Pluto has-mass-kg equal-to 1.27e22.
# Pluto has-density equal-to 2.06.
# Pluto has-abo equal-to 0.55.
# Pluto has-vo equal-to 13.6.
# Pluto has-rotate equal-to -6.39.
# Moon has-radius equal-to 1738.0.
# Moon has-mass-kg equal-to 7.35e22.
# Moon has-density equal-to 3.34.
# Moon has-abo equal-to 0.12.
# Moon has-vo equal-to -12.7.
# Moon has-rotate equal-to 'Stable'.
# Phobos has-radius equal-to 11.0.
# Phobos has-mass-kg equal-to 1.08e16.
# Phobos has-density equal-to 1.9.
# Phobos has-abo equal-to 0.06.
# Phobos has-vo equal-to 11.3.
# Phobos has-rotate equal-to 'Stable'.
# Deimos has-radius equal-to 6.0.
# Deimos has-mass-kg equal-to 1.80e15.
# Deimos has-density equal-to 1.8.
# Deimos has-abo equal-to 0.07.
# Deimos has-vo equal-to 12.3.
# Deimos has-rotate equal-to 'Stable'.
# Metis has-radius equal-to 20.0.
# Metis has-mass-kg equal-to 9.56e16.
# Metis has-density equal-to 2.8.
# Metis has-abo equal-to 0.05.
# Metis has-vo equal-to 17.5.
# Adrastea has-radius equal-to 10.0.
# Adrastea has-mass-kg equal-to 1.91e16.
# Adrastea has-density equal-to 4.5.
# Adrastea has-abo equal-to 0.05.
# Adrastea has-vo equal-to 18.7.
# Amalthea has-radius equal-to 94.0.
# Amalthea has-mass-kg equal-to 3.5e18.
# Amalthea has-density equal-to 1.0.
# Amalthea has-abo equal-to 0.05.
# Amalthea has-vo equal-to 14.1.
# Amalthea has-rotate equal-to 'Stable'.
# Thebe has-radius equal-to 50.0.
# Thebe has-mass-kg equal-to 7.77e17.
# Thebe has-density equal-to 1.5.
# Thebe has-abo equal-to 0.05.
# Thebe has-vo equal-to 16.0.
# Thebe has-rotate equal-to 'Stable'.
# Io has-radius equal-to 1821.0.
# Io has-mass-kg equal-to 8.93e22.
# Io has-density equal-to 3.53.
# Io has-abo equal-to 0.61.
# Io has-vo equal-to 5.0.
# Io has-rotate equal-to 'Stable'.
# Europa has-radius equal-to 1565.0.
# Europa has-mass-kg equal-to 4.80e22.
# Europa has-density equal-to 2.99.
# Europa has-abo equal-to 0.64.
# Europa has-vo equal-to 5.3.
# Europa has-rotate equal-to 'Stable'.
# Ganymede has-radius equal-to 2634.0.
# Ganymede has-mass-kg equal-to 1.48e23.
# Ganymede has-density equal-to 1.94.
# Ganymede has-abo equal-to 0.42.
# Ganymede has-vo equal-to 4.6.
# Ganymede has-rotate equal-to 'Stable'.
# Callisto has-radius equal-to 2403.0.
# Callisto has-mass-kg equal-to 1.08e23.
# Callisto has-density equal-to 1.85.
# Callisto has-abo equal-to 0.20.
# Callisto has-vo equal-to 5.6.
# Callisto has-rotate equal-to 'Stable'.
# Leda has-radius equal-to 8.0.
# Leda has-mass-kg equal-to 5.68e15.
# Leda has-density equal-to 2.7.
# Leda has-vo equal-to 20.2.
# Himalia has-radius equal-to 93.0.
# Himalia has-mass-kg equal-to 9.56e18.
# Himalia has-density equal-to 2.8.
# Himalia has-vo equal-to 15.0.
# Himalia has-rotate equal-to 0.4.
# Lysithea has-radius equal-to 18.0.
# Lysithea has-mass-kg equal-to 7.77e16.
# Lysithea has-density equal-to 3.1.
# Lysithea has-vo equal-to 18.2.
# Elara has-radius equal-to 38.0.
# Elara has-mass-kg equal-to 7.77e17.
# Elara has-density equal-to 3.3.
# Elara has-vo equal-to 16.6.
# Elara has-rotate equal-to 0.5.
# Ananke has-radius equal-to 15.0.
# Ananke has-mass-kg equal-to 3.82e16.
# Ananke has-density equal-to 2.7.
# Ananke has-vo equal-to 18.9.
# Carme has-radius equal-to 20.0.
# Carme has-mass-kg equal-to 9.56e16.
# Carme has-density equal-to 2.8.
# Carme has-vo equal-to 17.9.
# Pasiphae has-radius equal-to 25.0.
# Pasiphae has-mass-kg equal-to 1.91e17.
# Pasiphae has-density equal-to 2.9.
# Pasiphae has-vo equal-to 16.9.
# Sinope has-radius equal-to 18.0.
# Sinope has-mass-kg equal-to 7.77e16.
# Sinope has-density equal-to 3.1.
# Sinope has-vo equal-to 18.0.
# Pan has-radius equal-to 10.0.
# Pan has-abo equal-to 0.5.
# Atlas has-radius equal-to 15.0.
# Atlas has-abo equal-to 0.9.
# Atlas has-vo equal-to 18.0.
# Prometheus has-radius equal-to 46.0.
# Prometheus has-mass-kg equal-to 2.70e17.
# Prometheus has-density equal-to 0.7.
# Prometheus has-abo equal-to 0.6.
# Prometheus has-vo equal-to 15.8.
# Pandora has-radius equal-to 42.0.
# Pandora has-mass-kg equal-to 2.20e17.
# Pandora has-density equal-to 0.7.
# Pandora has-abo equal-to 0.9.
# Pandora has-vo equal-to 16.5.
# Epimetheus has-radius equal-to 57.0.
# Epimetheus has-mass-kg equal-to 5.59e17.
# Epimetheus has-density equal-to 0.6.
# Epimetheus has-abo equal-to 0.8.
# Epimetheus has-vo equal-to 15.7.
# Epimetheus has-rotate equal-to 'Stable'.
# Janus has-radius equal-to 89.0.
# Janus has-mass-kg equal-to 1.98e18.
# Janus has-density equal-to 0.65.
# Janus has-abo equal-to 0.8.
# Janus has-vo equal-to 14.5.
# Janus has-rotate equal-to 'Stable'.
# Mimas has-radius equal-to 199.0.
# Mimas has-mass-kg equal-to 3.75e19.
# Mimas has-density equal-to 1.14.
# Mimas has-abo equal-to 0.5.
# Mimas has-vo equal-to 12.9.
# Mimas has-rotate equal-to 'Stable'.
# Enceladus has-radius equal-to 249.0.
# Enceladus has-mass-kg equal-to 7.30e19.
# Enceladus has-density equal-to 1.12.
# Enceladus has-abo equal-to 0.99.
# Enceladus has-vo equal-to 11.7.
# Enceladus has-rotate equal-to 'Stable'.
# Tethys has-radius equal-to 530.0.
# Tethys has-mass-kg equal-to 6.22e20.
# Tethys has-density equal-to 1.00.
# Tethys has-abo equal-to 0.9.
# Tethys has-vo equal-to 10.2.
# Tethys has-rotate equal-to 'Stable'.
# Telesto has-radius equal-to 15.0.
# Telesto has-abo equal-to 0.5.
# Telesto has-vo equal-to 18.7.
# Calypso has-radius equal-to 13.0.
# Calypso has-abo equal-to 0.6.
# Calypso has-vo equal-to 19.0.
# Dione has-radius equal-to 560.0.
# Dione has-mass-kg equal-to 1.05e21.
# Dione has-density equal-to 1.44.
# Dione has-abo equal-to 0.7.
# Dione has-vo equal-to 10.4.
# Dione has-rotate equal-to 'Stable'.
# Helene has-radius equal-to 16.0.
# Helene has-abo equal-to 0.7.
# Helene has-vo equal-to 18.4.
# Rhea has-radius equal-to 764.0.
# Rhea has-mass-kg equal-to 2.31e21.
# Rhea has-density equal-to 1.24.
# Rhea has-abo equal-to 0.7.
# Rhea has-vo equal-to 9.7.
# Rhea has-rotate equal-to 'Stable'.
# Titan has-radius equal-to 2575.0.
# Titan has-mass-kg equal-to 1.35e23.
# Titan has-density equal-to 1.88.
# Titan has-abo equal-to 0.21.
# Titan has-vo equal-to 8.3.
# Titan has-rotate equal-to 'Stable'.
# Hyperion has-radius equal-to 143.0.
# Hyperion has-mass-kg equal-to 1.77e19.
# Hyperion has-density equal-to 1.4.
# Hyperion has-abo equal-to 0.3.
# Hyperion has-vo equal-to 14.2.
# Hyperion has-rotate equal-to 'Chaotic'.
# Iapetus has-radius equal-to 718.0.
# Iapetus has-mass-kg equal-to 1.59e21.
# Iapetus has-density equal-to 1.02.
# Iapetus has-abo equal-to 0.21.
# Iapetus has-vo equal-to 11.1.
# Iapetus has-rotate equal-to 'Stable'.
# Phoebe has-radius equal-to 110.0.
# Phoebe has-density equal-to 1.6.
# Phoebe has-abo equal-to 0.06.
# Phoebe has-vo equal-to 16.5.
# Phoebe has-rotate equal-to 0.4.
# Cordelia has-radius equal-to 13.0.
# Cordelia has-abo equal-to 0.07.
# Cordelia has-vo equal-to 24.0.
# Ophelia has-radius equal-to 16.0.
# Ophelia has-abo equal-to 0.07.
# Ophelia has-vo equal-to 24.0.
# Bianca has-radius equal-to 22.0.
# Bianca has-abo equal-to 0.07.
# Bianca has-vo equal-to 23.0.
# Cressida has-radius equal-to 33.0.
# Cressida has-abo equal-to 0.07.
# Cressida has-vo equal-to 22.0.
# Desdemona has-radius equal-to 29.0.
# Desdemona has-abo equal-to 0.07.
# Desdemona has-vo equal-to 22.0.
# Juliet has-radius equal-to 42.0.
# Juliet has-abo equal-to 0.07.
# Juliet has-vo equal-to 22.0.
# Portia has-radius equal-to 55.0.
# Portia has-abo equal-to 0.07.
# Portia has-vo equal-to 21.0.
# Rosalind has-radius equal-to 27.0.
# Rosalind has-abo equal-to 0.07.
# Rosalind has-vo equal-to 22.0.
# Belinda has-radius equal-to 34.0.
# Belinda has-abo equal-to 0.07.
# Belinda has-vo equal-to 22.0.
# Puck has-radius equal-to 77.0.
# Puck has-abo equal-to 0.07.
# Puck has-vo equal-to 20.0.
# Miranda has-radius equal-to 236.0.
# Miranda has-mass-kg equal-to 6.59e19.
# Miranda has-density equal-to 1.20.
# Miranda has-abo equal-to 0.27.
# Miranda has-vo equal-to 16.5.
# Miranda has-rotate equal-to 'Stable'.
# Ariel has-radius equal-to 581.0.
# Ariel has-mass-kg equal-to 1.35e21.
# Ariel has-density equal-to 1.67.
# Ariel has-abo equal-to 0.34.
# Ariel has-vo equal-to 14.4.
# Ariel has-rotate equal-to 'Stable'.
# Umbriel has-radius equal-to 585.0.
# Umbriel has-mass-kg equal-to 1.17e21.
# Umbriel has-density equal-to 1.40.
# Umbriel has-abo equal-to 0.18.
# Umbriel has-vo equal-to 15.3.
# Umbriel has-rotate equal-to 'Stable'.
# Titania has-radius equal-to 789.0.
# Titania has-mass-kg equal-to 3.53e21.
# Titania has-density equal-to 1.71.
# Titania has-abo equal-to 0.27.
# Titania has-vo equal-to 14.0.
# Titania has-rotate equal-to 'Stable'.
# Oberon has-radius equal-to 761.0.
# Oberon has-mass-kg equal-to 3.01e21.
# Oberon has-density equal-to 1.63.
# Oberon has-abo equal-to 0.24.
# Oberon has-vo equal-to 14.2.
# Oberon has-rotate equal-to 'Stable'.
# Caliban has-radius equal-to 40.0.
# Caliban has-abo equal-to 0.07.
# Caliban has-vo equal-to 21.9.
# Stephano has-radius equal-to 15.0.
# Stephano has-abo equal-to 0.07.
# Stephano has-vo equal-to 24.3.
# Sycorax has-radius equal-to 80.0.
# Sycorax has-abo equal-to 0.07.
# Sycorax has-vo equal-to 20.4.
# Prospero has-radius equal-to 20.0.
# Prospero has-abo equal-to 0.07.
# Prospero has-vo equal-to 23.2.
# Setebos has-radius equal-to 20.0.
# Setebos has-abo equal-to 0.07.
# Setebos has-vo equal-to 23.3.
# Naiad has-radius equal-to 29.0.
# Naiad has-abo equal-to 0.06.
# Naiad has-vo equal-to 25.0.
# Thalassa has-radius equal-to 40.0.
# Thalassa has-abo equal-to 0.06.
# Thalassa has-vo equal-to 24.0.
# Despina has-radius equal-to 74.0.
# Despina has-abo equal-to 0.06.
# Despina has-vo equal-to 23.0.
# Galatea has-radius equal-to 79.0.
# Galatea has-abo equal-to 0.06.
# Galatea has-vo equal-to 23.0.
# Larissa has-radius equal-to 96.0.
# Larissa has-abo equal-to 0.06.
# Larissa has-vo equal-to 21.0.
# Proteus has-radius equal-to 209.0.
# Proteus has-abo equal-to 0.06.
# Proteus has-vo equal-to 20.0.
# Triton has-radius equal-to 1353.0.
# Triton has-mass-kg equal-to 2.15e22.
# Triton has-density equal-to 2.05.
# Triton has-abo equal-to 0.7.
# Triton has-vo equal-to 13.6.
# Triton has-rotate equal-to 'Stable'.
# Nereid has-radius equal-to 170.0.
# Nereid has-abo equal-to 0.2.
# Nereid has-vo equal-to 18.7.
# Charon has-radius equal-to 603.0.
# Charon has-mass-kg equal-to 1.52e21.
# Charon has-density equal-to 1.72.
# Charon has-abo equal-to 0.32.
# Charon has-vo equal-to 15.5.
# Charon has-rotate equal-to 'Stable'.
# Nix has-radius equal-to 23.0.
# Nix has-mass-kg lower-than 2e18.
# Nix has-vo equal-to 22.9.
# Hydra has-radius equal-to 30.0.
# Hydra has-mass-kg lower-than 2e18.
# Hydra has-vo equal-to 23.4.

# %%
onto = Ontology("cnl/string",orbit_cnl+physics_cnl, 
                    evaluator = lambda e:eval(e,globals(),locals()), 
                    graph_attribute_formatter = graph_attribute_formatter)

# %%
editor=CnlEditBox('solarsystem.encnl')
editor
# Out:
# Welcome to CogniPy
# VBox(children=(Output(), OntoeditWidget(layout=Layout(height='100%', width='90%'), value='Sun is a star.\nIf a…

# %% [markdown]
# Lets define the function that will build the ontology based on the dict of ontology editors and the optional additional editor for testing purposes. All it is doing it is concatenaiting the values of all the editors and puts them into the newly created ontology object.

# %%
onto = Ontology("cnl/string",editor.getvalue()+orbit_cnl+physics_cnl, 
                    evaluator = lambda e:eval(e,globals(),locals()), 
                    graph_attribute_formatter = graph_attribute_formatter)

# %% [markdown]
# The ontology object alows you to draw the materialised graph using several layout algorythms. Lets draw our base ontology.

# %%
onto.select_instances_of("a star")
# Out:
#   Instance  has-rotate  has-vo  has-density   has-mass-kg  has-radius
# 0      Sun        24.6     -26         1.41  1.990000e+30    695000.0

# %%
onto.select_instances_of("a dwarf-planet")
# Out:
#   Instance orbits  has-discovery-year   has-mass-kg  has-vo  has-abo  \
# 0    Pluto    Sun                1930  1.270000e+22    13.6     0.55
#
#   has-discoverer  has-rotate  has-radius  has-period  \
# 0       Tombaugh       -6.39      1150.0       90550
#
#    has-semimajor-axis-1000-km  has-eccentricity has-index  has-density
# 0                     5913520              0.25        IX         2.06

# %%
onto.select_instances_of("a planet")
# Out:
#   Instance orbits has-discoverer  has-abo  has-vo  has-density  \
# 0  Neptune    Sun          Adams     0.41     7.8         1.64
# 1   Saturn    Sun           None     0.47     0.7         0.69
# 2     Mars    Sun           None     0.15    -2.0         3.93
# 3    Earth    Sun           None     0.30     NaN         5.52
# 4    Venus    Sun           None     0.65    -4.4         5.24
# 5   Uranus    Sun       Herschel     0.51     5.5         1.32
# 6  Mercury    Sun           None     0.11    -1.9         5.43
# 7  Jupiter    Sun           None     0.52    -2.7         1.33
#
#    has-semimajor-axis-1000-km  has-discovery-year  has-period  \
# 0                     4504300              1846.0    60190.00
# 1                     1429400                 NaN    10759.50
# 2                      227940                 NaN      686.98
# 3                      149600                 NaN      365.26
# 4                      108200                 NaN      224.70
# 5                     2870990              1781.0    30685.00
# 6                       57910                 NaN       87.97
# 7                      778330                 NaN     4332.71
#
#    has-eccentricity  has-radius   has-mass-kg  has-rotate has-index
# 0              0.01     24766.0  1.020000e+26        0.67      VIII
# 1              0.06     60268.0  5.680000e+26        0.45        VI
# 2              0.09      3397.0  6.420000e+23        1.03        IV
# 3              0.02      6378.0  5.970000e+24        0.99       III
# 4              0.01      6052.0  4.870000e+24     -243.00        II
# 5              0.05     25559.0  8.680000e+25       -0.72       VII
# 6              0.21      2440.0  3.300000e+23       58.60         I
# 7              0.05     71492.0  1.900000e+27        0.41         V

# %%
onto.select_instances_of("a moon that orbits Jupiter")
# Out:
#       Instance   orbits  has-radius  has-semimajor-axis-1000-km has-index  \
# 0        Carme  Jupiter        20.0                       22600        XI
# 1    Harpalyke  Jupiter         NaN                       21132      XXII
# 2    Megaclite  Jupiter         NaN                       23911       XIX
# 3   Callirrhoe  Jupiter         NaN                       24100      XVII
# 4           Io  Jupiter      1821.0                         422         I
# 5        Thebe  Jupiter        50.0                         222       XIV
# 6     Amalthea  Jupiter        94.0                         181         V
# 7        Elara  Jupiter        38.0                       11737       VII
# 8     Chaldene  Jupiter         NaN                       23387       XXI
# 9     Lysithea  Jupiter        18.0                       11720         X
# 10    Callisto  Jupiter      2403.0                        1883        IV
# 11    Pasiphae  Jupiter        25.0                       23500      VIII
# 12     Taygete  Jupiter         NaN                       23312        XX
# 13     Erinome  Jupiter         NaN                       23168       XXV
# 14       Metis  Jupiter        20.0                         128       XVI
# 15    Ganymede  Jupiter      2634.0                        1070       III
# 16        Leda  Jupiter         8.0                       11094      XIII
# 17      Sinope  Jupiter        18.0                       23700        IX
# 18    Adrastea  Jupiter        10.0                         129        XV
# 19    Themisto  Jupiter         NaN                        7507     XVIII
# 20     Iocaste  Jupiter         NaN                       20216      XXIV
# 21      Europa  Jupiter      1565.0                         671        II
# 22      Ananke  Jupiter        15.0                       21200       XII
# 23     Himalia  Jupiter        93.0                       11480        VI
# 24      Isonoe  Jupiter         NaN                       23078      XXVI
#
#     has-density  has-period  has-vo  has-discovery-year has-discoverer  \
# 0          2.80     -692.00    17.9                1938      Nicholson
# 1           NaN         NaN     NaN                2000       Sheppard
# 2           NaN         NaN     NaN                2000       Sheppard
# 3           NaN         NaN     NaN                2000       Sheppard
# 4          3.53        1.77     5.0                1610        Galileo
# 5          1.50        0.67    16.0                1979        Synnott
# 6          1.00        0.50    14.1                1892        Barnard
# 7          3.30      259.65    16.6                1905        Perrine
# 8           NaN         NaN     NaN                2000       Sheppard
# 9          3.10      259.22    18.2                1938      Nicholson
# 10         1.85       16.69     5.6                1610        Galileo
# 11         2.90     -735.00    16.9                1908        Melotte
# 12          NaN         NaN     NaN                2000       Sheppard
# 13          NaN         NaN     NaN                2000       Sheppard
# 14         2.80        0.29    17.5                1979        Synnott
# 15         1.94        7.15     4.6                1610        Galileo
# 16         2.70      238.72    20.2                1974          Kowal
# 17         3.10     -758.00    18.0                1914      Nicholson
# 18         4.50        0.30    18.7                1979         Jewitt
# 19          NaN         NaN     NaN                2000       Sheppard
# 20          NaN         NaN     NaN                2000       Sheppard
# 21         2.99        3.55     5.3                1610        Galileo
# 22         2.70     -631.00    18.9                1951      Nicholson
# 23         2.80      250.57    15.0                1904        Perrine
# 24          NaN         NaN     NaN                2000       Sheppard
#
#     has-eccentricity   has-mass-kg has-rotate  has-abo
# 0               0.21  9.560000e+16       None      NaN
# 1                NaN           NaN       None      NaN
# 2                NaN           NaN       None      NaN
# 3                NaN           NaN       None      NaN
# 4               0.00  8.930000e+22     Stable     0.61
# 5               0.02  7.770000e+17     Stable     0.05
# 6               0.00  3.500000e+18     Stable     0.05
# 7               0.21  7.770000e+17        0.5      NaN
# 8                NaN           NaN       None      NaN
# 9               0.11  7.770000e+16       None      NaN
# 10              0.01  1.080000e+23     Stable     0.20
# 11              0.38  1.910000e+17       None      NaN
# 12               NaN           NaN       None      NaN
# 13               NaN           NaN       None      NaN
# 14              0.00  9.560000e+16       None     0.05
# 15              0.00  1.480000e+23     Stable     0.42
# 16              0.15  5.680000e+15       None      NaN
# 17              0.28  7.770000e+16       None      NaN
# 18              0.00  1.910000e+16       None     0.05
# 19               NaN           NaN       None      NaN
# 20               NaN           NaN       None      NaN
# 21              0.01  4.800000e+22     Stable     0.64
# 22              0.17  3.820000e+16       None      NaN
# 23              0.16  9.560000e+18        0.4      NaN
# 24               NaN           NaN       None      NaN

# %%
onto.draw_graph(layout='force directed',show={"relations", 'attributes'})
