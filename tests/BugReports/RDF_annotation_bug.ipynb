# %%
from cognipy.ontology import Ontology

# %%
onto = Ontology("rdf/uri","https://protege.stanford.edu/ontologies/pizza/pizza.owl")

# %%
#onto.draw_graph()

# %%
print(onto.as_rdf())
# Out:
# <?xml version = '1.0' encoding = 'UTF-8'?>
# <rdf:RDF xmlns="http://www.co-ode.org/ontologies/pizza/pizza.owl#" xml:base="http://www.co-ode.org/ontologies/pizza/pizza.owl" xmlns:owl="http://www.w3.org/2002/07/owl#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#" xmlns:skos2="http://unknown.prefix/skos#">
#   <owl:Ontology rdf:about="http://www.co-ode.org/ontologies/pizza/pizza.owl#" />
#   <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Annotation properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#   <!-- http://unknown.prefix/skos#altLabel -->
#   <owl:AnnotationProperty rdf:about="http://unknown.prefix/skos#altLabel" />
#   <!-- http://unknown.prefix/skos#definition -->
# ...

# %%
print(onto.as_cnl())
# Out:
# Amespace:'http://www.co-ode.org/ontologies/pizza/pizza.owl#'.
# America is something.
# England is something.
# France is something.
# Germany is something.
# Italy is something.
# Every-single-thing is had-base by at-most one thing.
# If X has-ingredient something that has-ingredient Y then X has-ingredient Y.
# Every-single-thing is had-topping by at-most one thing.
# Every-single-thing is is-base-of by at-most one thing.
# If X is-ingredient-of something that is-ingredient-of Y then X is-ingredient-of Y.
# Every "American" is a "NamedPizza".
# Every "AmericanHot" is a "NamedPizza".
# Every "AnchoviesTopping" is a "FishTopping".
# Every "ArtichokeTopping" is a "VegetableTopping".
# Every "AsparagusTopping" is a "VegetableTopping".
# Every "Cajun" is a "NamedPizza".
# Every "CajunSpiceTopping" is a "HerbSpiceTopping".
# Every "CajunSpiceTopping" is not a "RosemaryTopping".
# Every "CaperTopping" is a "VegetableTopping".
# Every "Capricciosa" is a "NamedPizza".
# ...

# %% [markdown]
# ## Annotations were read from the rdf uri (listed above at the end in Annotation: xxx.)

# %%
print(onto.as_cnl())
# Out:
# America is something.
# England is something.
# France is something.
# Germany is something.
# Italy is something.
# Every-single-thing is had-base by at-most one thing.
# If X has-ingredient something that has-ingredient Y then X has-ingredient Y.
# Every-single-thing is had-topping by at-most one thing.
# Every-single-thing is is-base-of by at-most one thing.
# If X is-ingredient-of something that is-ingredient-of Y then X is-ingredient-of Y.
# Every "American" is a "NamedPizza".
# Every "AmericanHot" is a "NamedPizza".
# Every "AnchoviesTopping" is a "FishTopping".
# Every "ArtichokeTopping" is a "VegetableTopping".
# Every "AsparagusTopping" is a "VegetableTopping".
# Every "Cajun" is a "NamedPizza".
# Every "CajunSpiceTopping" is a "HerbSpiceTopping".
# Every "CajunSpiceTopping" is not a "RosemaryTopping".
# Every "CaperTopping" is a "VegetableTopping".
# Every "Capricciosa" is a "NamedPizza".
# Every "Caprina" is a "NamedPizza".
# Every "CheeseTopping" is a "PizzaTopping".
# ...

# %%
ontocnl = Ontology("cnl/string", onto.as_cnl())

# %%
print(ontocnl.as_cnl())
# Out:
# America is something.
# England is something.
# France is something.
# Germany is something.
# Italy is something.
# Every-single-thing is had-base by at-most one thing.
# If X has-ingredient something that has-ingredient Y then X has-ingredient Y.
# Every-single-thing is had-topping by at-most one thing.
# Every-single-thing is ised-base-of by at-most one thing.
# If X is-ingredient-of something that is-ingredient-of Y then X is-ingredient-of Y.
# Every "American" is a "NamedPizza".
# Every "AmericanHot" is a "NamedPizza".
# Every "AnchoviesTopping" is a "FishTopping".
# Every "ArtichokeTopping" is a "VegetableTopping".
# Every "AsparagusTopping" is a "VegetableTopping".
# Every "Cajun" is a "NamedPizza".
# Every "CajunSpiceTopping" is a "HerbSpiceTopping".
# No "CajunSpiceTopping" is a "RosemaryTopping".
# Every "CaperTopping" is a "VegetableTopping".
# Every "Capricciosa" is a "NamedPizza".
# Every "Caprina" is a "NamedPizza".
# Every "CheeseTopping" is a "PizzaTopping".
# ...

# %% [markdown]
# ## But below when converting cnl to rdf the annotations were lost...

# %%
print(ontocnl.as_rdf())
# Out:
# <?xml version = '1.0' encoding = 'UTF-8'?>
# <rdf:RDF xmlns="http://www.cognitum.eu/onto#" xml:base="http://www.cognitum.eu/onto" xmlns:owl="http://www.w3.org/2002/07/owl#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#" xmlns:skos2="http://unknown.prefix/skos#">
#   <owl:Ontology rdf:about="http://www.cognitum.eu/onto#" />
#   <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Annotation properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#   <!-- http://unknown.prefix/skos#altLabel -->
#   <owl:AnnotationProperty rdf:about="http://unknown.prefix/skos#altLabel" />
#   <!-- http://unknown.prefix/skos#definition -->
#   <owl:AnnotationProperty rdf:about="http://unknown.prefix/skos#definition" />
#   <!-- http://unknown.prefix/skos#prefLabel -->
# ...
